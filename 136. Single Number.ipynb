# %% [markdown]
# Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
# You must implement a solution with a linear runtime complexity and use only constant extra space.
#
#
#
# Example 1:
#
# Input: nums = [2,2,1]
# Output: 1
# Example 2:
#
# Input: nums = [4,1,2,1,2]
# Output: 4
# Example 3:
#
# Input: nums = [1]
# Output: 1

# %%
from typing import List
class Solution:
    def singleNumber1(self, nums: List[int]) -> int:
        seen = set()
        for num in nums:
            if num in seen:
                seen.remove(num)
            else:
                seen.add(num)
        return seen.pop()
    def singleNumber2(self, nums: List[int]) -> int:
        xor= 0
        for a in nums:
            xor ^= a
        return xor
test = Solution()
test.singleNumber2([4,1,2,1,2])
# Out:
# 4

# %% [markdown]
# ![1694835180849.png](attachment:1694835180849.png)

# %% [markdown]
# XOR 运算
